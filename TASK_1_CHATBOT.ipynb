# %% [markdown]
# <a href="https://colab.research.google.com/github/MSJahnavi/CODSOFT/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Chatbot: Hello! How can I assist you today?")

while True:
    user = input("You: ").lower()

    if "hello" in user:
        print("Chatbot: Hello there! How can I help you today?")
    elif "hi" in user:
        print("Chatbot: Hi! What's on your mind? How can I assist you?")
    elif "hey" in user:
        print("Chatbot: Hey! How can I assist you today? Is there something specific you'd like to know or discuss?")
    elif "what's up" in user:
        print("Chatbot: Not much, just here to help. What's on your mind? How can I assist you?")
    elif "what are you doing?" in user:
        print("Chatbot: I'm just a chatbot, but I'm functioning well! What can I assist you with?")
    elif "what is your name?" in user:
        print("Chatbot: You can call me chatbot. How can I assist you today?")
    elif "how are you?" in user:
        print("Chatbot: I'm just a computer program, so I don't have feelings, but I'm here to help you! What can I assist you with?")
    elif "help" in user:
        print("Chatbot: Sure, I can help with various topics. What do you need assistance with today?")
    elif "tell me a joke" in user:
        print("Chatbot: Why did the scarecrow win an award? Because he was outstanding in his field! Do you want to hear another joke?")
        user_input = input().lower()
        if "yes" in user_input:
            print("Chatbot: Here's another one: What do you get when you cross a snowman and a vampire? Frostbite!")
        else:
            print("Chatbot: Alright, if you have any other questions or need assistance, feel free to ask.")
    elif "bye" in user:
        print("Chatbot: Goodbye! Have a great day! If you ever want to chat again, don't hesitate to return. Is there anything else you'd like to know before you go?")
        user_input = input().lower()
        if "no" in user_input:
            break
    elif "what's the weather like today?" in user:
        print("Chatbot: I'm sorry, I don't have access to real-time weather information. Is there anything else you'd like to know or discuss?")
    elif "recommend a book" in user:
        print("Chatbot: What genre are you interested in for book recommendations?")
        user_input = input("User: ").lower()
        if "mystery" in user_input:
            print("Chatbot: I recommend 'The Girl with the Dragon Tattoo' by Stieg Larsson. Do you want more book recommendations or have another question in mind?")
            user_input = input().lower()
            if "yes" in user_input:
                print("Chatbot: Great! What other genre would you like to explore next?")
            else:
                print("Chatbot: Okay, feel free to reach out if you have more book-related questions in the future.")
        elif "science fiction" in user_input:
            print("Chatbot: I recommend 'Dune' by Frank Herbert. Is there a specific author or genre you prefer for your next read?")
        elif "fantasy" in user_input:
            print("Chatbot: I recommend 'The Name of the Wind' by Patrick Rothfuss. Would you like more book recommendations or have another question in mind?")
            user_input = input().lower()
            if "yes" in user_input:
                print("Chatbot: Excellent! What other genre are you interested in?")
            else:
                print("Chatbot: If you ever need more book suggestions, don't hesitate to ask.")
        else:
            print("Chatbot: I'm sorry, I don't have a recommendation for that genre. Is there something else you'd like to explore?")
    # You can continue this pattern for the remaining elif blocks.
    elif "recommend a movie" in user:
        print("Chatbot: What genre of movie are you in the mood for?")
        user_input = input("User: ").lower()
        if "action" in user_input:
            print("Chatbot: I recommend 'Mad Max: Fury Road' starring Tom Hardy and Charlize Theron. Do you want more movie recommendations or have another question in mind?")
            user_input = input().lower()
            if "yes" in user_input:
                print("Chatbot: Great! What other genre are you interested in?")
            else:
                print("Chatbot: If you have more movie-related questions in the future, feel free to ask.")
        elif "comedy" in user_input:
            print("Chatbot: I recommend 'Superbad' starring Jonah Hill and Michael Cera. Is there a specific actor or genre you prefer for your next movie recommendation?")
        elif "drama" in user_input:
            print("Chatbot: I recommend 'The Social Network' directed by David Fincher. Would you like more movie recommendations or have another question in mind?")
            user_input = input().lower()
            if "yes" in user_input:
                print("Chatbot: Excellent! What other genre are you interested in?")
            else:
                print("Chatbot: If you have more movie-related questions in the future, don't hesitate to reach out.")
        else:
            print("Chatbot: I'm sorry, I don't have a recommendation for that genre. Is there something else you'd like to explore?")
    elif "recommend a restaurant" in user:
        print("Chatbot: What type of cuisine are you in the mood for?")
        user_input = input("User: ").lower()
        if "italian" in user_input:
            print("Chatbot: I recommend 'Pasta Paradise' for delicious Italian dishes. Do you want more restaurant suggestions or have another question in mind?")
            user_input = input().lower()
            if "yes" in user_input:
                print("Chatbot: Great! What other cuisine are you interested in?")
            else:
                print("Chatbot: If you have more restaurant-related questions in the future, feel free to ask.")
        elif "sushi" in user_input:
            print("Chatbot: I recommend 'Sushi Sensation' for fresh sushi rolls. Is there a specific dish or type of cuisine you prefer for your next restaurant recommendation?")
        else:
            print("Chatbot: I'm sorry, I don't have a recommendation for that cuisine. Is there something else you'd like to explore?")
    elif "suggest a song" in user:
        print("Chatbot: What mood or genre of song are you looking for?")
        user_input = input("User: ").lower()
        if "happy" in user_input:
            print("Chatbot: How about 'Happy' by Pharrell Williams? Do you want more song recommendations or have another question in mind?")
            user_input = input().lower()
            if "yes" in user_input:
                print("Chatbot: Great! What other genre or mood are you interested in?")
            else:
                print("Chatbot: If you have more music-related questions in the future, don't hesitate to reach out.")
        elif "rock" in user_input:
            print("Chatbot: I recommend 'Bohemian Rhapsody' by Queen. Is there a specific artist or genre you prefer for your next song recommendation?")
        else:
            print("Chatbot: I'm sorry, I don't have a specific song recommendation. Is there something else you'd like to explore?")
    elif "ask artist and suggest a song" in user:
        print("Chatbot: Which artist would you like a song recommendation from?")
        user_input = input("User: ").lower()
        if "the beatles" in user_input:
            print("Chatbot: I recommend 'Hey Jude' by The Beatles. Would you like more song recommendations from the same artist or have another question in mind?")
            user_input = input().lower()
            if "yes" in user_input:
                print("Chatbot: Excellent! What other songs by The Beatles are you interested in?")
            else:
                print("Chatbot: If you have more music-related questions in the future, feel free to ask.")
        elif "elton john" in user_input:
            print("Chatbot: I recommend 'Rocket Man' by Elton John. Is there another artist you'd like a song recommendation from, or do you have a different question in mind?")
        else:
            print("Chatbot: I'm sorry, I don't have a recommendation for that artist. Is there something else you'd like to explore?")
    elif "travelling ideas" in user:
        print("Chatbot: Where would you like to travel or what type of travel experience are you looking for?")
        user_input = input("User: ")
        print(f"Chatbot: How about exploring {user_input}? You can visit historical sites, try local cuisine, and enjoy the culture. Is there a specific destination you'd like more information about, or do you have another question in mind?")
        print("User: ")
        user_input = input()
        print(f"Chatbot: That sounds like a fantastic choice! Have you considered any particular activities or attractions in {user_input}? Would you like recommendations for accommodations or local experiences?")
    elif "makeup ideas" in user:
        print("Chatbot: What kind of makeup look are you interested in? Are you looking for a natural look, a glamorous style, or something else?")
        user_input = input()
        print(f"Chatbot: I can suggest makeup ideas for a {user_input} look. Is there a particular occasion or style you have in mind, or do you have another makeup-related question?")
        print("User: ")
        user_input = input()
        print(f"Chatbot: Got it! For a {user_input} makeup look, you might consider using specific products or techniques. Do you have any specific questions about makeup products or application?")
    elif "webseries" in user:
        print("Chatbot: What genre of web series are you looking for? Are you interested in drama, comedy, sci-fi, or something else?")
        user_input = input()
        print(f"Chatbot: I can recommend some popular web series in the {user_input} genre. Is there a specific series you'd like to know more about, or do you have another web series-related question?")
        print("User: ")
        user_input = input()
        print(f"Chatbot: Great choice! If you're looking for a {user_input} web series, I can provide details about the plot, cast, and where to watch it. Do you have a specific series in mind, or would you like a general recommendation?")
    elif "future goals" in user:
        print("Chatbot: What are your future goals or aspirations? Are you looking to further your education, start a new career, or achieve a personal milestone?")
        user_input = input()
        print(f"Chatbot: That sounds exciting! Working towards {user_input} is a great goal. Do you have a plan in mind, or are you looking for advice on how to achieve your goals?")
        print("User: ")
        user_input = input()
        print(f"Chatbot: It's important to have a plan. What steps have you taken so far to reach your goal, and where do you think you might need assistance or guidance?")
    elif "internships" in user:
        print("Chatbot: Are you looking for information on specific types of internships? Are you interested in summer internships, paid opportunities, or something else?")
        user_input = input()
        print(f"Chatbot: I can provide information about {user_input} internships. Is there a particular field or company you're interested in, or do you have another internship-related question?")
        print("User: ")
        user_input = input()
        print(f"Chatbot: Excellent! Researching specific companies can be helpful. Have you prepared a resume and cover letter for your internship applications, or would you like tips on creating a strong application?")
    elif "jobs" in user:
        print("Chatbot: Are you looking for job search tips or specific job recommendations? What type of job are you interested in, and have you identified any preferred industries?")
        user_input = input()
        print(f"Chatbot: Your job search preferences are important. Do you have a specific location in mind for your job search, or would you like assistance with creating a job search strategy?")
        print("User: ")
        user_input = input()
        print(f"Chatbot: That's a good approach! Networking and online job boards can be valuable resources. Have you updated your LinkedIn profile or connected with professionals in your industry of interest?")
    elif "mobiles" in user:
        print("Chatbot: Are you interested in a particular type of mobile device or have specific mobile-related questions? Are you looking for information on the latest smartphone models, mobile accessories, or technical assistance?")
        user_input = input()
        print(f"Chatbot: Mobile technology is continually evolving. Is there a specific brand or feature you're interested in, or do you have other mobile-related inquiries?")
        print("User: ")
        user_input = input()
        print(f"Chatbot: Great! When selecting a mobile device, it's essential to consider your specific needs. Do you require a device with a high-quality camera, ample storage, or specific apps for your work or hobbies?")
    elif "yes" in user:
        print("Chatbot: Great! How can I assist you further?")
    elif "no" in user:
        print("Chatbot: Okay, if you have any more questions or need assistance in the future, feel free to ask.")
    elif "thank you" in user:
        print("Chatbot: You're welcome! If you have any more questions or need assistance, feel free to ask.")
    else:
        print("Chatbot: I'm sorry, I don't understand your query. Is there another topic or question you'd like to discuss?")
# Out:
# Chatbot: Hello! How can I assist you today?
# You: hey
# Chatbot: Hey! How can I assist you today? Is there something specific you'd like to know or discuss?
# You: what's up
# Chatbot: Not much, just here to help. What's on your mind? How can I assist you?
# You: what is your name?
# Chatbot: You can call me chatbot. How can I assist you today?
# You: suggest a song
# Chatbot: What mood or genre of song are you looking for?
# User: happy
# Chatbot: How about 'Happy' by Pharrell Williams? Do you want more song recommendations or have another question in mind?
# no
# Chatbot: If you have more music-related questions in the future, don't hesitate to reach out.
# You: tell me a joke
# Chatbot: Why did the scarecrow win an award? Because he was outstanding in his field! Do you want to hear another joke?
# yes
# Chatbot: Here's another one: What do you get when you cross a snowman and a vampire? Frostbite!
# You: thank you
# ...
